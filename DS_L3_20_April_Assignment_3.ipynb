# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
url_train = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Assignments/DataScience/L2/train.csv"
train = pd.read_csv(url_train)
train.head(10)
train
# Out:
#       Age  Attrition  ... YearsWithCurrManager    ID
# 0      41          1  ...                    5     0
# 1      49          0  ...                    7     1
# 2      37          1  ...                    0     2
# 3      33          0  ...                    0     3
# 4      27          0  ...                    2     4
# ...   ...        ...  ...                  ...   ...
# 1023   56          0  ...                    0  1023
# 1024   47          0  ...                    6  1024
# 1025   24          0  ...                    3  1025
# 1026   32          0  ...                    3  1026
# 1027   34          0  ...                    2  1027
#
# [1028 rows x 34 columns]

# %%
url_movies = "https://raw.githubusercontent.com/shala2020/shala2020.github.io/master/Lecture_Materials/Google_Colab_Notebooks/DataScience/L2/moviesData.csv"
movies = pd.read_csv(url_movies)
movies.head(10)
# Out:
#    Unnamed: 0                   title  ...            actor4                actor5
# 0           1             Filly Brown  ...     Emilio Rivera   Joseph Julian Soria
# 1           2                The Dish  ...          Tom Long        Genevieve Mooy
# 2           3     Waiting for Guffman  ...       Eugene Levy           Bob Balaban
# 3           4    The Age of Innocence  ...  Richard E. Grant          Alec McCowen
# 4           5             Malevolence  ...     Heather Magee        Richard Glover
# 5           6             Old Partner  ...               NaN                   NaN
# 6           7               Lady Jane  ...   Jill Bennett II  Helena Bonham Carter
# 7           8            Mad Dog Time  ...      Ellen Barkin            Diane Lane
# 8           9  Beauty Is Embarrassing  ...   Jonathan Dayton        Cliff Benjamin
# 9          10    The Snowtown Murders  ...       Craig Coyne         Richard Green
#
# [10 rows x 31 columns]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(movies.corr())
# vmin = -1, cmap='coolwarm', annot=True, mask = mask

# %%
 plt.figure(figsize=(10,10))
 mask = np.zeros_like(movies.corr(), dtype=np.bool)
 mask[np.triu_indices_from(mask)] = True
 sns.heatmap(movies.corr(),vmin = -1, cmap='coolwarm', annot=True, mask = mask)

# %%
train.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f574f459860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f440c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f42f3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f3057b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f2b6a20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f574f2ecc88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f29eef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f25f160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f25f1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f1c7668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f574f17b8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f1aeb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f162da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f117fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f0d5438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f574f0897b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f03ab38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f06eeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574f02b278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574efde5f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f574ef91978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574ef42cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574ef020b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574eeb3438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574eee37b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f574ee95b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574ee49eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574ee08278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574edb95f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f574edee978>]],
#       dtype=object)

# %%
sns.regplot(x = movies["imdb_rating"], 
            y = movies["audience_score"], ci = 95)

# %%
sns.regplot(x = movies["imdb_rating"], 
            y = movies["audience_score"], 
            marker="+", fit_reg=False, scatter_kws={"color":"red", "alpha":0.3, "s":200})

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
 
# Use the 'hue' argument to provide a factor variable
sns.lmplot(x="petal_length", y="petal_width", data=df, fit_reg=False, hue='species', legend=False)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %%
df = sns.load_dataset('iris')
p1=sns.kdeplot(df['sepal_width'], shade=True, color="r")
p1=sns.kdeplot(df['sepal_length'], shade=True, color="b")
p1=sns.kdeplot(df['petal_width'], shade=True, color="g")
p1=sns.kdeplot(df['petal_length'], shade=True, color="y")

# %%
sns.violinplot(x=df["species"], y=df["sepal_length"])

# %%
my_pal = {"versicolor": "green", "setosa": "blue", "virginica":"m"}

sns.violinplot(x=df["species"], y=df["sepal_length"] , palette=my_pal)
